# %% [markdown]
# This is a simple example on how you can use a jupyter notebook to train your model :)

# %%
import torch
import torch.nn as nn
from dataloaders import load_cifar10
from trainer import Trainer, compute_loss_and_accuracy
from task2 import create_plots

# %%
class ExampleModel(nn.Module):
    def __init__(self, image_channels, num_classes):
        """
        Is called when model is initialized.
        Args:
            image_channels. Number of color channels in image (3)
            num_classes: Number of classes we want to predict (10)
        """
        super().__init__()
        # TODO: Implement this function (Task  2a)
        num_filters = 32  # Set number of filters in first conv layer
        self.num_classes = num_classes
        # Define the convolutional layers
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(in_channels=image_channels, out_channels=32, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        # The output of feature_extractor will be [batch_size, num_filters, 16, 16]
        self.num_output_features = 128 * 4 * 4
        
        # Initialize our last fully connected layer
        # Inputs all extracted features from the convolutional layers
        # Outputs num_classes predictions, 1 for each class.
        # There is no need for softmax activation function, as this is
        # included with nn.CrossEntropyLoss
        self.classifier = nn.Sequential(
            nn.Linear(self.num_output_features, 64),  # Adjusted number of features
            nn.ReLU(),  # ReLU activation
            nn.Linear(64, num_classes)  # Outputs num_classes predictions
        )

    def forward(self, x):
        """
        Performs a forward pass through the model
        Args:
            x: Input image, shape: [batch_size, 3, 32, 32]
        """
        # TODO: Implement this function (Task  2a)
        batch_size = x.shape[0]
        
        x = self.feature_extractor(x)  
        x = x.view(-1, self.num_output_features)  
        out = self.classifier(x)  
        
        expected_shape = (batch_size, self.num_classes)
        assert out.shape == (
            batch_size,
            self.num_classes,
        ), f"Expected output of forward pass to be: {expected_shape}, but got: {out.shape}"
        return out

# %%
import utils 

utils.set_seed(0)
print(f"Using device: {utils.get_device()}")
epochs = 10
batch_size = 64
learning_rate = 5e-2
early_stop_count = 4
dataloaders = load_cifar10(batch_size)
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(
    batch_size, learning_rate, early_stop_count, epochs, model, dataloaders
)
trainer.train()
create_plots(trainer, "task2")
# Out:
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 273.02, Global step:    351, Validation Loss: 1.71, Validation Accuracy: 0.375
# Epoch: 0, Batches per seconds: 270.73, Global step:    702, Validation Loss: 1.38, Validation Accuracy: 0.499
# Epoch: 1, Batches per seconds: 265.94, Global step:   1053, Validation Loss: 1.33, Validation Accuracy: 0.504
# Epoch: 1, Batches per seconds: 263.87, Global step:   1404, Validation Loss: 1.25, Validation Accuracy: 0.563
# Epoch: 2, Batches per seconds: 259.69, Global step:   1755, Validation Loss: 1.07, Validation Accuracy: 0.617
# Epoch: 2, Batches per seconds: 260.51, Global step:   2106, Validation Loss: 0.97, Validation Accuracy: 0.663
# Epoch: 3, Batches per seconds: 259.53, Global step:   2457, Validation Loss: 0.90, Validation Accuracy: 0.685
# Epoch: 3, Batches per seconds: 259.52, Global step:   2808, Validation Loss: 0.99, Validation Accuracy: 0.646
# Epoch: 4, Batches per seconds: 259.71, Global step:   3159, Validation Loss: 0.85, Validation Accuracy: 0.703
# Epoch: 4, Batches per seconds: 260.52, Global step:   3510, Validation Loss: 0.83, Validation Accuracy: 0.711
# Epoch: 5, Batches per seconds: 259.36, Global step:   3861, Validation Loss: 0.80, Validation Accuracy: 0.722
# Epoch: 5, Batches per seconds: 259.97, Global step:   4212, Validation Loss: 0.78, Validation Accuracy: 0.732
# Epoch: 6, Batches per seconds: 258.20, Global step:   4563, Validation Loss: 0.79, Validation Accuracy: 0.735
# Epoch: 6, Batches per seconds: 260.83, Global step:   4914, Validation Loss: 0.83, Validation Accuracy: 0.734
# Epoch: 7, Batches per seconds: 261.97, Global step:   5265, Validation Loss: 0.80, Validation Accuracy: 0.735
# Early stop criteria met
# Early stopping.

# %%
trainer.report_final_accuracies()
# Out:
# Final Training Loss: 0.352, Final Training Accuracy: 0.885
# Final Validation Loss: 0.798, Final Validation Accuracy: 0.735
# Final Test Loss: 0.836, Final Test Accuracy: 0.736
